# %%
# SGI 지수 데이터 다운로드 코드 (불러오기 + 출력)

# %%
# SGI 지수 데이터 불러오기

import requests
url = 'http://apis.data.go.kr/B500001/drghtSGIIdex_20211020/operInfoList_20211020'
params = {'serviceKey': '6488a795990f407b454be4d113aaab7c80c35c401a39af42a0736443438dfcd0',
          'pageNo' : '1', 'numOfRows' : '10', 'obsrvtCd' : '11749', 'stDt' : '20240101', 'edDt' : '20241231', '_type' : 'json' }

# %%
# 데이터 출력
response = requests.get(url, params=params)
print(response.content)
# Out:
# b'{"response":{"header":{"resultCode":"00","resultMsg":"NORMAL SERVICE."},"body":{"items":{"item":[{"anldt":20240101,"anlrst":"\xec\xa0\x95\xec\x83\x81","obsrvtcd":11749,"obsrvtnm":"\xeb\x8f\x99\xed\x95\xb4\xea\xb7\x80\xec\x9a\xb4","ugrwtrl":7.296},{"anldt":20240102,"anlrst":"\xec\xa0\x95\xec\x83\x81","obsrvtcd":11749,"obsrvtnm":"\xeb\x8f\x99\xed\x95\xb4\xea\xb7\x80\xec\x9a\xb4","ugrwtrl":7.296},{"anldt":20240103,"anlrst":"\xec\xa0\x95\xec\x83\x81","obsrvtcd":11749,"obsrvtnm":"\xeb\x8f\x99\xed\x95\xb4\xea\xb7\x80\xec\x9a\xb4","ugrwtrl":7.296},{"anldt":20240104,"anlrst":"\xec\xa0\x95\xec\x83\x81","obsrvtcd":11749,"obsrvtnm":"\xeb\x8f\x99\xed\x95\xb4\xea\xb7\x80\xec\x9a\xb4","ugrwtrl":7.296},{"anldt":20240105,"anlrst":"\xec\xa0\x95\xec\x83\x81","obsrvtcd":11749,"obsrvtnm":"\xeb\x8f\x99\xed\x95\xb4\xea\xb7\x80\xec\x9a\xb4","ugrwtrl":7.208},{"anldt":20240106,"anlrst":"\xec\xa0\x95\xec\x83\x81","obsrvtcd":11749,"obsrvtnm":"\xeb\x8f\x99\xed\x95\xb4\xea\xb7\x80\xec\x9a\xb4","ugrwtrl":7.208}
# ...
